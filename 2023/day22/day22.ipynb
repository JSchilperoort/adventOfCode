# %%
import pandas as pd
import numpy as np
import os
import sys
from tqdm import tqdm

# %% [markdown]
# ### Read the data

# %%
current_path = os.getcwd()
day = int(current_path.split('day')[1])

fn = 'day' + str(day) + '.txt'

file_content = open(fn).read().split('\n')

test_fn = 'day' + str(day) + 'test.txt'

test_file_content = open(test_fn).read().split('\n')

# %% [markdown]
# ### Part 1

# %%
class Brick:
    def __init__(self, brick_string, name):
        self.name = name
        end1, end2 = brick_string.split('~')
        self.x1, self.y1, self.z1 = [int(x) for x in end1.split(',')]
        self.x2, self.y2, self.z2 = [int(x) for x in end2.split(',')]

    @property
    def lowest_z(self):
        return min(self.z1, self.z2)
    
    @property
    def highest_z(self):
        return max(self.z1, self.z2)
    
    @property
    def lowest_y(self):
        return min(self.y1, self.y2)
    
    @property
    def highest_y(self):
        return max(self.y1, self.y2)
    
    @property
    def lowest_x(self):
        return min(self.x1, self.x2)
    
    @property
    def highest_x(self):
        return max(self.x1, self.x2)
    
    @property
    def on_ground(self):
        return self.lowest_z == 1
    
    def drop_one(self):
        self.z1 -= 1
        self.z2 -= 1

    def drop_n(self, n):
        self.z1 -= n
        self.z2 -= n
    
    def x_overlap(self, other):
        return self.lowest_x <= other.highest_x and self.highest_x >= other.lowest_x
    
    def y_overlap(self, other):
        return self.lowest_y <= other.highest_y and self.highest_y >= other.lowest_y

    def __repr__(self):
        return 'Brick {}: ({}, {}, {}) ~ ({}, {}, {})'.format(self.name, self.x1, self.y1, self.z1, self.x2, self.y2, self.z2)
    
    def __eq__(self, other):
        return self.x1 == other.x1 and self.y1 == other.y1 and self.z1 == other.z1 and self.x2 == other.x2 and self.y2 == other.y2 and self.z2 == other.z2


class BrickSpace:
    def __init__(self, working_file_content):

        self.bricks = [Brick(x, 'A') for x in working_file_content]

    def move(self):
        # sort bricks on lowest z value
        print("Moving bricks..")
        self.bricks.sort(key=lambda x: x.lowest_z, reverse=False)
        for brick in tqdm(self.bricks):
            distance_to_nearest_brick_below = self.get_distance_to_nearest_brick_below(brick)
            brick.drop_n(distance_to_nearest_brick_below)
            # while self.can_move(brick):
            #     brick.drop_one()

    def get_distance_to_nearest_brick_below(self, brick):
        nearest_overlapping_brick = None
        distance = 9999999999
        for other_brick in self.bricks:
            if brick == other_brick:
                continue
            if brick.x_overlap(other_brick) and brick.y_overlap(other_brick):
                if (brick.lowest_z - other_brick.highest_z) > 1 and (brick.lowest_z - other_brick.highest_z) < distance:
                    nearest_overlapping_brick = other_brick
                    distance = (brick.lowest_z - other_brick.highest_z)
        if nearest_overlapping_brick:
            return distance - 1
        return 0

    def can_move(self, brick):
        if brick.on_ground:
                return False
        lowest_z = brick.lowest_z
        for other_brick in self.bricks:
            # not current brick
            if brick == other_brick:
                continue
            # check if brick is directly below
            if other_brick.highest_z == lowest_z - 1 and brick.x_overlap(other_brick) and brick.y_overlap(other_brick):
                return False
        return True
    
    def supports(self, brick):
        other_bricks = list()
        highest_z = brick.highest_z
        for other_brick in self.bricks:
            # not current brick
            if brick == other_brick:
                continue
            # check if brick is directly above
            if other_brick.lowest_z == highest_z + 1 and brick.x_overlap(other_brick) and brick.y_overlap(other_brick):
                other_bricks.append(other_brick)
        return other_bricks
    
    def is_supported_by(self, brick):
        other_bricks = list()
        lowest_z = brick.lowest_z
        for other_brick in self.bricks:
            # not current brick
            if brick == other_brick:
                continue
            # check if brick is directly above
            if other_brick.lowest_z == lowest_z - 1 and brick.x_overlap(other_brick) and brick.y_overlap(other_brick):
                other_bricks.append(other_brick)
        return other_bricks
    
    def is_essential(self, brick):
        # a brick is essential if any brick that it supports is supported by only this one
        bricks_that_are_supported_by_this = self.supports(brick)
        if len(bricks_that_are_supported_by_this) == 0:
            return False

        for other_brick in bricks_that_are_supported_by_this:
            bricks_that_support_other_brick = self.is_supported_by(other_brick)
            if len(bricks_that_support_other_brick) == 1:
                return True
            
        return False
        
    def n_bricks_that_can_be_disintegrated(self):
        n = 0
        print("Checking number of disintegratable bricks..")
        for brick in tqdm(self.bricks):
            if not self.is_essential(brick):
                n += 1
        return n

    
    def __repr__(self):
        # sort bricks
        self.bricks.sort(key=lambda x: x.lowest_z, reverse=True)

        return_str = ''
        for brick in self.bricks:
            return_str += str(brick)
            if not self.is_essential(brick):
                return_str += ' can be disintegrated'
            return_str += '\n'
            
        return return_str

                
working_file_content = file_content

bricks = BrickSpace(working_file_content)
bricks.move()
print(bricks.n_bricks_that_can_be_disintegrated())
# Out:
# Moving bricks..
#   0%|          | 0/1370 [00:00<?, ?it/s]
# 100%|██████████| 1370/1370 [00:03<00:00, 376.22it/s]
# Checking number of disintegratable bricks..
# 100%|██████████| 1370/1370 [00:02<00:00, 648.66it/s]
# 511

# %% [markdown]
# ### Part 2

# %%
infile = open("day22.txt")
#infile = open("sample.txt")

cubes = {}

for i, line in enumerate(infile):
    p0, p1 = (tuple(map(int, p.split(","))) for p in line.strip().split("~"))
    cubes[i] = (p0, p1)

gminx = min(min(x0, x1) for ((x0, _, _), (x1, _, _)) in cubes.values())
gminy = min(min(y0, y1) for ((_, y0, _), (_, y1, _)) in cubes.values())
gmaxx = max(max(x0, x1) for ((x0, _, _), (x1, _, _)) in cubes.values())
gmaxy = max(max(y0, y1) for ((_, y0, _), (_, y1, _)) in cubes.values())

grid = dict(((x,y,0), -1) for x in range(gminx, gmaxx+1) for y in range(gminy, gmaxy+1))

# lower cubes starting from the lowest ones, stopping when they collide with something
to_lower = list(range(len(cubes)))
to_lower.sort(key = lambda i: min(cubes[i][0][2], cubes[i][1][2]))
resting_on = {}
while to_lower:

    c_i = to_lower.pop(0)
    c = cubes[c_i]

    rest = set()
    rest_z = -1

    cminx = min(c[0][0], c[1][0])
    cminy = min(c[0][1], c[1][1])
    cminz = min(c[0][2], c[1][2])
    cmaxx = max(c[0][0], c[1][0])
    cmaxy = max(c[0][1], c[1][1])
    cmaxz = max(c[0][2], c[1][2])

    for ((gx, gy, gz), gi) in grid.items():
        if gx >= cminx and gx <= cmaxx and gy >= cminy and gy <= cmaxy:
            if gz > rest_z:
                rest_z = gz
                rest = set([gi])
            elif gz == rest_z:
                rest.add(gi)

    print(f"{c_i} resting on {rest}")
    resting_on[c_i] = rest

    new_z = rest_z + 1
    delta_z = new_z - cminz
    c = ((c[0][0], c[0][1], c[0][2] + delta_z),
         (c[1][0], c[1][1], c[1][2] + delta_z))
    cminz = min(c[0][2], c[1][2])
    cmaxz = max(c[0][2], c[1][2])

    for z in range(cminz, cmaxz+1):
        for y in range(cminy, cmaxy+1):
            for x in range(cminx, cmaxx+1):
                assert((x, y, z) not in grid)
                grid[(x, y, z)] = c_i

can_disintegrate = set(range(len(cubes)))
for rs in resting_on.values():
    if len(rs) == 1:
        ri, = rs
        can_disintegrate.discard(ri)

print(can_disintegrate)
print(len(can_disintegrate))

infile = open("day22.txt")
#infile = open("sample.txt")

cubes = {}

for i, line in enumerate(infile):
    p0, p1 = (tuple(map(int, p.split(","))) for p in line.strip().split("~"))
    cubes[i] = (p0, p1)

gminx = min(min(x0, x1) for ((x0, _, _), (x1, _, _)) in cubes.values())
gminy = min(min(y0, y1) for ((_, y0, _), (_, y1, _)) in cubes.values())
gmaxx = max(max(x0, x1) for ((x0, _, _), (x1, _, _)) in cubes.values())
gmaxy = max(max(y0, y1) for ((_, y0, _), (_, y1, _)) in cubes.values())

grid = dict(((x,y,0), -1) for x in range(gminx, gmaxx+1) for y in range(gminy, gmaxy+1))

# lower cubes starting from the lowest ones, stopping when they collide with something
to_lower = list(range(len(cubes)))
to_lower.sort(key = lambda i: min(cubes[i][0][2], cubes[i][1][2]))
resting_on = {}
while to_lower:

    c_i = to_lower.pop(0)
    c = cubes[c_i]

    rest = set()
    rest_z = -1

    cminx = min(c[0][0], c[1][0])
    cminy = min(c[0][1], c[1][1])
    cminz = min(c[0][2], c[1][2])
    cmaxx = max(c[0][0], c[1][0])
    cmaxy = max(c[0][1], c[1][1])
    cmaxz = max(c[0][2], c[1][2])

    for ((gx, gy, gz), gi) in grid.items():
        if gx >= cminx and gx <= cmaxx and gy >= cminy and gy <= cmaxy:
            if gz > rest_z:
                rest_z = gz
                rest = set([gi])
            elif gz == rest_z:
                rest.add(gi)

    print(f"{c_i} resting on {rest}")
    resting_on[c_i] = rest

    new_z = rest_z + 1
    delta_z = new_z - cminz
    c = ((c[0][0], c[0][1], c[0][2] + delta_z),
         (c[1][0], c[1][1], c[1][2] + delta_z))
    cminz = min(c[0][2], c[1][2])
    cmaxz = max(c[0][2], c[1][2])

    for z in range(cminz, cmaxz+1):
        for y in range(cminy, cmaxy+1):
            for x in range(cminx, cmaxx+1):
                assert((x, y, z) not in grid)
                grid[(x, y, z)] = c_i

total = 0
can_disintegrate = set(range(len(cubes)))
for ri, rs in resting_on.items():
    if len(rs) == 1:
        r, = rs
        can_disintegrate.discard(r)

for c_i in range(len(cubes)):
    if c_i in can_disintegrate:
        continue
    fall = set()
    new_fall = set([c_i])
    while len(new_fall) > len(fall):
        fall.update(new_fall)
        for c_j in range(len(cubes)):
            if all(ro in new_fall for ro in resting_on[c_j]):
                new_fall.add(c_j)
    total += len(fall) - 1

print(total)
# Out:
# 158 resting on {-1}
# 197 resting on {-1}
# 288 resting on {-1}
# 649 resting on {-1}
# 655 resting on {-1}
# 1018 resting on {-1}
# 1215 resting on {-1}
# 1345 resting on {-1}
# 295 resting on {-1}
# 429 resting on {1215}
# 506 resting on {-1}
# 1122 resting on {-1}
# 1140 resting on {-1}
# 1201 resting on {-1}
# 1274 resting on {-1}
# 1314 resting on {197}
# 5 resting on {288}
# 77 resting on {1122, 655}
# 79 resting on {295}
# 215 resting on {-1}
# 247 resting on {-1}
# 251 resting on {429}
# 460 resting on {-1}
# 659 resting on {-1}
# 853 resting on {1274}
# 889 resting on {-1}
# 1054 resting on {-1}
# 134 resting on {1201}
# 555 resting on {1054}
# 590 resting on {288}
# 752 resting on {1018}
# 1028 resting on {853}
# 4 resting on {247, 655}
# 160 resting on {429}
# 170 resting on {649}
# 175 resting on {659}
# 200 resting on {1314}
# 478 resting on {555}
# 589 resting on {429}
# 815 resting on {1201, 1140}
# 852 resting on {506}
# 1001 resting on {853}
# 1145 resting on {251}
# 876 resting on {134}
# 1212 resting on {200, 79}
# 1213 resting on {1028}
# 234 resting on {1212}
# 686 resting on {460}
# 791 resting on {251}
# 981 resting on {1001}
# 1170 resting on {589}
# 118 resting on {686}
# 361 resting on {234}
# 600 resting on {981, 1213, 791}
# 671 resting on {1170}
# 1073 resting on {361}
# 1118 resting on {981}
# 1154 resting on {118}
# 1248 resting on {1170}
# 521 resting on {361}
# 643 resting on {118}
# 782 resting on {1154}
# 994 resting on {1248}
# 19 resting on {1073}
# 59 resting on {1073}
# 808 resting on {671}
# 1178 resting on {521}
# 1249 resting on {600}
# 1350 resting on {782}
# 122 resting on {1118}
# 386 resting on {1248}
# 388 resting on {643}
# 480 resting on {1118}
# 497 resting on {521}
# 763 resting on {671}
# 1262 resting on {994}
# 44 resting on {480, 1249}
# 310 resting on {808}
# 588 resting on {994}
# 845 resting on {59}
# 1038 resting on {1073}
# 161 resting on {480}
# 302 resting on {44}
# 693 resting on {480}
# 809 resting on {310}
# 864 resting on {1038}
# 1092 resting on {1350}
# 1246 resting on {763, 118}
# 60 resting on {1246}
# 85 resting on {388}
# 420 resting on {809}
# 1063 resting on {122}
# 1196 resting on {809}
# 467 resting on {864}
# 622 resting on {497, 19, 1038}
# 747 resting on {1178}
# 869 resting on {1063}
# 1133 resting on {845}
# 1344 resting on {1063}
# 244 resting on {60}
# 487 resting on {864}
# 627 resting on {1246}
# 1356 resting on {809}
# 1210 resting on {1196}
# 1251 resting on {747}
# 511 resting on {1210}
# 841 resting on {244, 1350}
# 913 resting on {1210}
# 1007 resting on {693}
# 1329 resting on {1092}
# 632 resting on {420}
# 757 resting on {841}
# 856 resting on {1133, 487}
# 992 resting on {1210}
# 546 resting on {1007}
# 781 resting on {1007}
# 881 resting on {856}
# 103 resting on {992, 511}
# 259 resting on {511}
# 1100 resting on {511}
# 364 resting on {632}
# 851 resting on {781}
# 1057 resting on {856}
# 1143 resting on {103}
# 551 resting on {259}
# 712 resting on {364}
# 741 resting on {1143}
# 977 resting on {103}
# 99 resting on {1100}
# 163 resting on {977}
# 250 resting on {1057}
# 839 resting on {712}
# 847 resting on {851}
# 783 resting on {99}
# 792 resting on {163}
# 308 resting on {783}
# 1173 resting on {308}
# 894 resting on {792}
# 967 resting on {1173}
# 678 resting on {1173}
# 765 resting on {1173}
# 1022 resting on {308}
# 645 resting on {967}
# 750 resting on {1022}
# 1326 resting on {894, 1022}
# 8 resting on {750, 765, 678, 967}
# 140 resting on {678}
# 469 resting on {645}
# 827 resting on {1022}
# 1091 resting on {1326}
# 1218 resting on {678}
# 1259 resting on {645}
# 485 resting on {1022}
# 1205 resting on {1218}
# 1245 resting on {1218}
# 1264 resting on {469}
# 104 resting on {1245, 1205}
# 179 resting on {827}
# 236 resting on {750, 967}
# 425 resting on {1259, 469}
# 558 resting on {827, 485}
# 810 resting on {1326}
# 1327 resting on {750}
# 203 resting on {1327}
# 959 resting on {8, 1218}
# 996 resting on {179}
# 139 resting on {104}
# 241 resting on {996}
# 298 resting on {959}
# 352 resting on {1205}
# 624 resting on {485}
# 903 resting on {179}
# 1065 resting on {1264}
# 26 resting on {1245, 959}
# 86 resting on {425}
# 256 resting on {624, 645}
# 662 resting on {810, 1091}
# 1159 resting on {1327}
# 1302 resting on {425}
# 422 resting on {1159}
# 698 resting on {959}
# 930 resting on {256}
# 309 resting on {256}
# 598 resting on {352}
# 987 resting on {139}
# 1183 resting on {903}
# 1208 resting on {662}
# 68 resting on {86}
# 350 resting on {256}
# 518 resting on {662}
# 1104 resting on {598}
# 1337 resting on {698}
# 458 resting on {309}
# 636 resting on {86, 1302}
# 1238 resting on {1208}
# 1243 resting on {1208}
# 383 resting on {636}
# 905 resting on {350}
# 53 resting on {458}
# 629 resting on {458}
# 928 resting on {905, 1243, 1238}
# 935 resting on {1337}
# 1172 resting on {68}
# 444 resting on {53}
# 495 resting on {636}
# 724 resting on {935}
# 824 resting on {928}
# 1224 resting on {629}
# 238 resting on {905}
# 531 resting on {53}
# 1050 resting on {1224}
# 1197 resting on {724}
# 1306 resting on {1172}
# 94 resting on {531}
# 152 resting on {1172}
# 395 resting on {935}
# 591 resting on {1172}
# 596 resting on {724}
# 631 resting on {724}
# 184 resting on {591}
# 187 resting on {1224}
# 323 resting on {824}
# 1002 resting on {152}
# 1320 resting on {531}
# 181 resting on {395}
# 285 resting on {1002}
# 341 resting on {94}
# 381 resting on {323}
# 543 resting on {323}
# 1068 resting on {1320}
# 61 resting on {187}
# 519 resting on {285}
# 702 resting on {1068}
# 925 resting on {1320}
# 116 resting on {543}
# 169 resting on {187}
# 246 resting on {925}
# 417 resting on {181}
# 479 resting on {1320}
# 605 resting on {381}
# 120 resting on {1068}
# 896 resting on {381, 543}
# 1020 resting on {169}
# 1125 resting on {246}
# 1231 resting on {285}
# 1237 resting on {417}
# 421 resting on {479}
# 432 resting on {417}
# 135 resting on {1125}
# 142 resting on {1237}
# 315 resting on {1020}
# 581 resting on {1125}
# 955 resting on {421, 246}
# 1354 resting on {421}
# 437 resting on {581, 285}
# 891 resting on {581}
# 1151 resting on {1237}
# 91 resting on {891, 1231}
# 452 resting on {432}
# 768 resting on {955}
# 758 resting on {142}
# 1202 resting on {142}
# 1364 resting on {1202}
# 473 resting on {91}
# 1074 resting on {768}
# 1124 resting on {1202, 758}
# 1244 resting on {452}
# 938 resting on {1074}
# 965 resting on {758}
# 37 resting on {938}
# 1225 resting on {938}
# 1347 resting on {1124}
# 1134 resting on {1124}
# 1166 resting on {1347}
# 227 resting on {1166}
# 557 resting on {1166}
# 997 resting on {1347}
# 222 resting on {227}
# 663 resting on {1134}
# 1254 resting on {1166}
# 84 resting on {663}
# 293 resting on {227}
# 563 resting on {997, 663}
# 651 resting on {997}
# 320 resting on {1254}
# 550 resting on {222}
# 934 resting on {227}
# 340 resting on {293}
# 413 resting on {320}
# 523 resting on {320, 222}
# 816 resting on {222}
# 828 resting on {293}
# 130 resting on {563}
# 667 resting on {828}
# 756 resting on {816}
# 402 resting on {667}
# 453 resting on {320}
# 1155 resting on {130}
# 1310 resting on {550}
# 129 resting on {756}
# 527 resting on {340}
# 780 resting on {84}
# 1060 resting on {402}
# 29 resting on {1155, 413}
# 416 resting on {756}
# 481 resting on {130}
# 1138 resting on {780}
# 330 resting on {527}
# 704 resting on {129}
# 740 resting on {1060}
# 785 resting on {416}
# 1019 resting on {481}
# 1312 resting on {1138}
# 374 resting on {527}
# 431 resting on {1138}
# 447 resting on {453}
# 547 resting on {29}
# 727 resting on {527}
# 1362 resting on {330}
# 392 resting on {1312}
# 1268 resting on {1312}
# 435 resting on {704}
# 617 resting on {785}
# 769 resting on {1362}
# 843 resting on {1268}
# 1121 resting on {727}
# 1298 resting on {374}
# 198 resting on {1121}
# 690 resting on {1362}
# 892 resting on {435}
# 1117 resting on {1121}
# 1123 resting on {1298}
# 1285 resting on {617}
# 1340 resting on {1268}
# 1341 resting on {392}
# 1346 resting on {617}
# 574 resting on {1340}
# 1032 resting on {1340}
# 1158 resting on {769}
# 204 resting on {1158}
# 603 resting on {1158}
# 637 resting on {1032}
# 754 resting on {1346}
# 875 resting on {1032}
# 1084 resting on {198}
# 1109 resting on {1117}
# 321 resting on {1341}
# 376 resting on {754, 1123}
# 607 resting on {1032}
# 721 resting on {1032}
# 1021 resting on {1109}
# 25 resting on {574}
# 915 resting on {1084}
# 168 resting on {721}
# 499 resting on {875}
# 515 resting on {204}
# 1220 resting on {1109}
# 58 resting on {637, 607}
# 682 resting on {321}
# 960 resting on {1220}
# 1167 resting on {376}
# 269 resting on {321}
# 601 resting on {168}
# 722 resting on {168}
# 820 resting on {915}
# 885 resting on {722}
# 1261 resting on {601}
# 159 resting on {960, 820}
# 209 resting on {515}
# 290 resting on {499}
# 561 resting on {290}
# 736 resting on {1261}
# 1258 resting on {1341}
# 1263 resting on {885}
# 316 resting on {1263}
# 223 resting on {316}
# 503 resting on {209}
# 1357 resting on {1258}
# 117 resting on {1258}
# 303 resting on {1263}
# 389 resting on {736}
# 486 resting on {1357}
# 647 resting on {1263}
# 916 resting on {682}
# 1290 resting on {503}
# 45 resting on {486}
# 62 resting on {223}
# 355 resting on {1290}
# 464 resting on {303}
# 1174 resting on {561}
# 42 resting on {355}
# 151 resting on {117}
# 697 resting on {1174}
# 1056 resting on {916}
# 1311 resting on {1290}
# 385 resting on {697}
# 794 resting on {45}
# 133 resting on {1056}
# 173 resting on {133}
# 317 resting on {1056}
# 866 resting on {1311}
# 874 resting on {1056}
# 984 resting on {151}
# 414 resting on {317}
# 606 resting on {133}
# 630 resting on {464}
# 954 resting on {794}
# 149 resting on {874}
# 939 resting on {173, 606}
# 263 resting on {317}
# 638 resting on {984}
# 830 resting on {414}
# 973 resting on {984}
# 1105 resting on {973, 638}
# 633 resting on {638}
# 1005 resting on {263}
# 17 resting on {263}
# 909 resting on {633}
# 157 resting on {17}
# 1265 resting on {909}
# 199 resting on {633}
# 615 resting on {830}
# 760 resting on {909}
# 910 resting on {909}
# 144 resting on {760}
# 709 resting on {910}
# 802 resting on {199}
# 1368 resting on {144}
# 609 resting on {1265, 910}
# 789 resting on {802}
# 1322 resting on {954, 802}
# 87 resting on {144}
# 700 resting on {1322}
# 717 resting on {709}
# 793 resting on {609}
# 743 resting on {609}
# 1004 resting on {789}
# 1227 resting on {609}
# 520 resting on {717}
# 190 resting on {743}
# 500 resting on {1227}
# 1241 resting on {1227, 1004}
# 730 resting on {743}
# 742 resting on {190}
# 762 resting on {1004}
# 1287 resting on {1241}
# 186 resting on {1287}
# 322 resting on {742}
# 653 resting on {1287}
# 489 resting on {730}
# 759 resting on {87}
# 1198 resting on {742}
# 1284 resting on {186}
# 112 resting on {500}
# 501 resting on {762}
# 1013 resting on {762}
# 1181 resting on {762}
# 1230 resting on {759}
# 832 resting on {501}
# 1272 resting on {1284}
# 13 resting on {1198}
# 43 resting on {832}
# 281 resting on {1181}
# 338 resting on {1013, 1181}
# 491 resting on {1181}
# 1113 resting on {112}
# 216 resting on {13}
# 262 resting on {501}
# 1139 resting on {281}
# 1277 resting on {832}
# 772 resting on {216}
# 1127 resting on {1113}
# 231 resting on {1127}
# 301 resting on {491}
# 1295 resting on {1127}
# 124 resting on {1139, 301}
# 145 resting on {262}
# 932 resting on {772}
# 360 resting on {1277}
# 449 resting on {145}
# 1119 resting on {231}
# 1136 resting on {1295}
# 1156 resting on {449}
# 1228 resting on {932}
# 113 resting on {449}
# 148 resting on {1119}
# 454 resting on {360}
# 393 resting on {360}
# 1103 resting on {1119}
# 66 resting on {1295}
# 83 resting on {393}
# 532 resting on {1228}
# 729 resting on {148}
# 893 resting on {113}
# 1291 resting on {393}
# 14 resting on {1103}
# 433 resting on {893, 231}
# 456 resting on {393}
# 1339 resting on {66, 1119}
# 580 resting on {433}
# 746 resting on {456}
# 202 resting on {580}
# 559 resting on {14}
# 823 resting on {83}
# 1070 resting on {1291}
# 410 resting on {456}
# 901 resting on {580}
# 95 resting on {746}
# 472 resting on {746}
# 683 resting on {823}
# 838 resting on {410}
# 6 resting on {901}
# 78 resting on {1070}
# 156 resting on {202}
# 10 resting on {78}
# 176 resting on {78}
# 372 resting on {472}
# 701 resting on {6}
# 1232 resting on {78}
# 306 resting on {701}
# 332 resting on {95}
# 384 resting on {10}
# 923 resting on {372}
# 34 resting on {10}
# 132 resting on {838}
# 533 resting on {78}
# 1188 resting on {384}
# 1223 resting on {176}
# 1234 resting on {10}
# 1257 resting on {156}
# 1292 resting on {923}
# 411 resting on {176, 10}
# 998 resting on {34}
# 1240 resting on {701}
# 313 resting on {1234}
# 807 resting on {1223}
# 137 resting on {998}
# 253 resting on {34}
# 1040 resting on {1292}
# 346 resting on {1040}
# 538 resting on {313}
# 937 resting on {1188, 807}
# 343 resting on {253}
# 657 resting on {937}
# 1086 resting on {807}
# 608 resting on {937}
# 748 resting on {657}
# 777 resting on {253}
# 1041 resting on {657}
# 801 resting on {608}
# 1146 resting on {608}
# 468 resting on {1086}
# 825 resting on {343}
# 1010 resting on {1041}
# 1098 resting on {748}
# 279 resting on {801, 1146}
# 870 resting on {777}
# 1111 resting on {748}
# 64 resting on {1010}
# 494 resting on {1111}
# 545 resting on {825}
# 1222 resting on {1111}
# 1282 resting on {870}
# 65 resting on {64}
# 123 resting on {870}
# 345 resting on {1282}
# 1217 resting on {1222}
# 1280 resting on {64}
# 1342 resting on {494}
# 1355 resting on {1222}
# 276 resting on {65}
# 775 resting on {1217}
# 833 resting on {1280}
# 1271 resting on {1355}
# 96 resting on {775}
# 419 resting on {1342}
# 488 resting on {545}
# 650 resting on {1271}
# 1087 resting on {123}
# 289 resting on {345}
# 679 resting on {419}
# 806 resting on {1217}
# 983 resting on {1355}
# 1276 resting on {1355}
# 599 resting on {276}
# 849 resting on {419, 983}
# 1077 resting on {488}
# 136 resting on {1077}
# 196 resting on {849}
# 634 resting on {1276}
# 842 resting on {679}
# 990 resting on {419}
# 1269 resting on {1276}
# 1286 resting on {599}
# 287 resting on {849}
# 396 resting on {1269}
# 554 resting on {634, 1269}
# 1097 resting on {1077}
# 93 resting on {1097}
# 212 resting on {806}
# 380 resting on {990}
# 670 resting on {287}
# 465 resting on {670}
# 962 resting on {554}
# 1219 resting on {380}
# 356 resting on {670}
# 371 resting on {136}
# 428 resting on {380}
# 587 resting on {842}
# 97 resting on {428}
# 734 resting on {465}
# 1108 resting on {428}
# 1235 resting on {962}
# 1256 resting on {371}
# 9 resting on {962}
# 41 resting on {1219}
# 205 resting on {371}
# 260 resting on {428}
# 430 resting on {1219}
# 582 resting on {1256}
# 1034 resting on {962}
# 1177 resting on {587}
# 2 resting on {371}
# 311 resting on {260}
# 336 resting on {1034}
# 787 resting on {734}
# 834 resting on {1177}
# 80 resting on {41, 430}
# 193 resting on {787}
# 873 resting on {260}
# 1083 resting on {1108}
# 1163 resting on {834}
# 18 resting on {834}
# 31 resting on {873, 582}
# 442 resting on {9}
# 826 resting on {9}
# 829 resting on {212}
# 943 resting on {205}
# 291 resting on {18}
# 578 resting on {80}
# 1203 resting on {834}
# 47 resting on {578}
# 328 resting on {31}
# 401 resting on {826}
# 426 resting on {829}
# 512 resting on {336}
# 541 resting on {587}
# 575 resting on {943}
# 1299 resting on {193}
# 661 resting on {442}
# 707 resting on {575}
# 761 resting on {1299}
# 862 resting on {328}
# 1000 resting on {575}
# 1015 resting on {512}
# 1323 resting on {328}
# 56 resting on {291}
# 319 resting on {401}
# 855 resting on {761}
# 880 resting on {18}
# 1324 resting on {578}
# 180 resting on {541}
# 597 resting on {426}
# 1331 resting on {1299}
# 367 resting on {1323}
# 988 resting on {880}
# 1279 resting on {1323}
# 1348 resting on {880}
# 466 resting on {1279}
# 221 resting on {180}
# 274 resting on {761, 1331}
# 436 resting on {1279}
# 1303 resting on {988}
# 100 resting on {56}
# 297 resting on {221}
# 753 resting on {862}
# 1186 resting on {988}
# 126 resting on {1348}
# 459 resting on {100}
# 854 resting on {126}
# 1067 resting on {297}
# 1336 resting on {126}
# 191 resting on {753}
# 275 resting on {1336}
# 314 resting on {297}
# 593 resting on {459}
# 654 resting on {459}
# 30 resting on {854}
# 307 resting on {854}
# 549 resting on {593}
# 1043 resting on {314}
# 82 resting on {1043}
# 979 resting on {191}
# 986 resting on {30}
# 1069 resting on {1067}
# 178 resting on {593}
# 219 resting on {1043}
# 739 resting on {1336}
# 12 resting on {30}
# 153 resting on {986}
# 218 resting on {986}
# 351 resting on {307, 30}
# 536 resting on {549}
# 719 resting on {178}
# 732 resting on {1336}
# 1114 resting on {986}
# 1175 resting on {979}
# 498 resting on {351}
# 510 resting on {153}
# 524 resting on {1069}
# 840 resting on {218}
# 961 resting on {1114}
# 1026 resting on {732}
# 798 resting on {961}
# 813 resting on {498}
# 858 resting on {536}
# 16 resting on {218}
# 33 resting on {719}
# 282 resting on {858}
# 404 resting on {719}
# 978 resting on {510}
# 1148 resting on {498}
# 1278 resting on {524}
# 1353 resting on {524}
# 127 resting on {282}
# 235 resting on {1148}
# 304 resting on {961}
# 703 resting on {978}
# 976 resting on {840}
# 1189 resting on {858}
# 569 resting on {33}
# 610 resting on {1278}
# 699 resting on {1353, 307}
# 1226 resting on {304, 798}
# 1300 resting on {703}
# 1304 resting on {813}
# 232 resting on {282, 1189}
# 623 resting on {304}
# 898 resting on {1226}
# 952 resting on {699}
# 972 resting on {1226}
# 331 resting on {610}
# 400 resting on {898, 972}
# 844 resting on {1304}
# 249 resting on {623}
# 1080 resting on {331}
# 55 resting on {952}
# 1006 resting on {235}
# 1169 resting on {1080}
# 658 resting on {249}
# 922 resting on {331}
# 370 resting on {1006}
# 571 resting on {1006}
# 685 resting on {658}
# 1153 resting on {922}
# 424 resting on {370}
# 504 resting on {55}
# 616 resting on {922}
# 1338 resting on {370}
# 131 resting on {616, 1153}
# 936 resting on {616}
# 1206 resting on {658}
# 74 resting on {616}
# 229 resting on {936, 131}
# 675 resting on {370}
# 713 resting on {571}
# 958 resting on {685}
# 1369 resting on {1169}
# 167 resting on {936}
# 375 resting on {1369}
# 482 resting on {424, 1338, 675}
# 890 resting on {131}
# 993 resting on {616}
# 1131 resting on {713}
# 1333 resting on {424}
# 63 resting on {229, 167}
# 166 resting on {713}
# 214 resting on {1369}
# 553 resting on {229}
# 897 resting on {229}
# 283 resting on {553}
# 441 resting on {958}
# 694 resting on {958}
# 799 resting on {958}
# 908 resting on {993}
# 1275 resting on {897}
# 27 resting on {897}
# 102 resting on {63}
# 105 resting on {799}
# 337 resting on {167}
# 443 resting on {482}
# 921 resting on {1333}
# 1076 resting on {482}
# 484 resting on {443}
# 677 resting on {553}
# 111 resting on {27}
# 784 resting on {441}
# 681 resting on {784}
# 942 resting on {784}
# 1078 resting on {1076}
# 1165 resting on {1275, 102}
# 22 resting on {677}
# 165 resting on {484}
# 188 resting on {908, 102}
# 705 resting on {111}
# 980 resting on {337}
# 1193 resting on {942}
# 508 resting on {165}
# 602 resting on {1078}
# 1039 resting on {1193}
# 50 resting on {980}
# 1216 resting on {602}
# 121 resting on {1039}
# 233 resting on {50, 443}
# 397 resting on {22}
# 548 resting on {165}
# 1046 resting on {681}
# 811 resting on {1046}
# 861 resting on {397}
# 1307 resting on {1046}
# 795 resting on {121}
# 974 resting on {548}
# 1260 resting on {233}
# 584 resting on {861}
# 618 resting on {795}
# 733 resting on {861}
# 23 resting on {1260}
# 147 resting on {974}
# 225 resting on {795}
# 1294 resting on {733}
# 342 resting on {508, 23}
# 567 resting on {225}
# 625 resting on {147}
# 1157 resting on {225}
# 735 resting on {1260}
# 906 resting on {1157, 567}
# 1051 resting on {733}
# 1315 resting on {625}
# 264 resting on {1046}
# 403 resting on {1315}
# 1036 resting on {23}
# 1200 resting on {1315}
# 1316 resting on {735}
# 493 resting on {1316}
# 714 resting on {567}
# 1011 resting on {1316}
# 57 resting on {735}
# 648 resting on {1200}
# 940 resting on {264}
# 1106 resting on {1316}
# 21 resting on {1036}
# 438 resting on {1307, 264, 811}
# 477 resting on {648}
# 918 resting on {940, 438}
# 1055 resting on {477}
# 1102 resting on {1011}
# 1149 resting on {940}
# 530 resting on {1106}
# 583 resting on {1102}
# 878 resting on {1102}
# 1363 resting on {438}
# 109 resting on {1363}
# 296 resting on {530}
# 579 resting on {878}
# 639 resting on {878}
# 1144 resting on {878}
# 1283 resting on {648}
# 1360 resting on {1055}
# 88 resting on {530}
# 394 resting on {918}
# 516 resting on {579}
# 595 resting on {1200}
# 902 resting on {1283, 477}
# 904 resting on {1360}
# 24 resting on {109}
# 217 resting on {1144}
# 716 resting on {109}
# 788 resting on {109}
# 1359 resting on {904}
# 107 resting on {1283}
# 192 resting on {516}
# 195 resting on {1359}
# 708 resting on {639}
# 817 resting on {516}
# 895 resting on {394}
# 439 resting on {296, 88}
# 564 resting on {788}
# 1066 resting on {708}
# 1330 resting on {716}
# 185 resting on {788}
# 848 resting on {1330}
# 377 resting on {848, 403}
# 715 resting on {185}
# 726 resting on {564}
# 857 resting on {185}
# 1033 resting on {192, 817}
# 1199 resting on {195}
# 1229 resting on {1066}
# 562 resting on {1033}
# 565 resting on {1330}
# 1112 resting on {1229}
# 1293 resting on {1033}
# 242 resting on {726}
# 540 resting on {1293}
# 642 resting on {857}
# 1 resting on {565}
# 248 resting on {1112}
# 357 resting on {242}
# 1047 resting on {1293}
# 210 resting on {540}
# 1332 resting on {642}
# 28 resting on {540}
# 349 resting on {540}
# 1064 resting on {1047}
# 327 resting on {1}
# 566 resting on {349}
# 800 resting on {28}
# 812 resting on {248}
# 1045 resting on {1}
# 445 resting on {812}
# 941 resting on {1332}
# 528 resting on {327}
# 535 resting on {800, 566}
# 999 resting on {1064}
# 1184 resting on {812}
# 70 resting on {812}
# 81 resting on {941}
# 1081 resting on {1045}
# 1253 resting on {566}
# 1318 resting on {566}
# 1361 resting on {941}
# 640 resting on {941}
# 669 resting on {1318, 535}
# 907 resting on {1361}
# 684 resting on {999}
# 1321 resting on {535}
# 720 resting on {907}
# 1328 resting on {640}
# 266 resting on {669}
# 379 resting on {720}
# 745 resting on {720}
# 766 resting on {1081}
# 1075 resting on {1321, 669}
# 1325 resting on {1321}
# 7 resting on {1328}
# 405 resting on {379}
# 755 resting on {766}
# 786 resting on {720}
# 950 resting on {745}
# 1334 resting on {745}
# 455 resting on {755}
# 502 resting on {1325}
# 1214 resting on {907, 766}
# 108 resting on {786}
# 228 resting on {1075}
# 245 resting on {379}
# 737 resting on {266, 1075}
# 956 resting on {755}
# 1209 resting on {455}
# 36 resting on {502}
# 128 resting on {455}
# 230 resting on {956}
# 115 resting on {1214}
# 271 resting on {36}
# 344 resting on {737}
# 863 resting on {1209}
# 1132 resting on {7}
# 664 resting on {230}
# 718 resting on {245}
# 982 resting on {1132}
# 900 resting on {1132}
# 1270 resting on {271}
# 189 resting on {1270}
# 552 resting on {982}
# 790 resting on {271}
# 1009 resting on {245}
# 1160 resting on {664}
# 1130 resting on {900}
# 1152 resting on {863}
# 268 resting on {900}
# 318 resting on {900}
# 378 resting on {1270}
# 573 resting on {189}
# 966 resting on {1160}
# 1094 resting on {1160}
# 334 resting on {966}
# 613 resting on {1130}
# 1042 resting on {1152}
# 38 resting on {573}
# 492 resting on {1152}
# 778 resting on {1130}
# 886 resting on {1042}
# 1161 resting on {1152}
# 1343 resting on {1042}
# 213 resting on {1094}
# 450 resting on {318}
# 475 resting on {886}
# 612 resting on {886}
# 796 resting on {573}
# 821 resting on {886}
# 1358 resting on {378}
# 71 resting on {38}
# 207 resting on {268}
# 513 resting on {213}
# 805 resting on {778}
# 1052 resting on {1343}
# 1129 resting on {613}
# 339 resting on {796, 38}
# 635 resting on {778, 613}
# 710 resting on {1358}
# 883 resting on {492}
# 1024 resting on {207}
# 284 resting on {796}
# 1128 resting on {1052}
# 680 resting on {207}
# 1030 resting on {513}
# 619 resting on {284}
# 1017 resting on {883}
# 226 resting on {1030}
# 476 resting on {1017}
# 771 resting on {1017}
# 859 resting on {1128}
# 407 resting on {680}
# 470 resting on {1017}
# 1313 resting on {859}
# 110 resting on {476}
# 286 resting on {619}
# 462 resting on {1313}
# 665 resting on {226}
# 48 resting on {771}
# 887 resting on {859}
# 358 resting on {110}
# 738 resting on {1313}
# 867 resting on {771, 470}
# 254 resting on {738}
# 556 resting on {867}
# 804 resting on {665}
# 924 resting on {1313, 887}
# 52 resting on {738}
# 224 resting on {254}
# 586 resting on {924}
# 770 resting on {286}
# 822 resting on {867}
# 1335 resting on {358}
# 1351 resting on {556}
# 927 resting on {556}
# 947 resting on {804}
# 101 resting on {1351}
# 359 resting on {52}
# 576 resting on {822}
# 776 resting on {822}
# 1059 resting on {586}
# 1093 resting on {1351}
# 1195 resting on {556, 822}
# 1297 resting on {1335}
# 933 resting on {1093}
# 1164 resting on {1297}
# 1192 resting on {1093}
# 20 resting on {1195}
# 270 resting on {359}
# 277 resting on {933}
# 408 resting on {1164}
# 953 resting on {1059}
# 1142 resting on {1297}
# 261 resting on {1093}
# 265 resting on {20}
# 415 resting on {277}
# 418 resting on {776}
# 514 resting on {953}
# 744 resting on {270}
# 944 resting on {1192}
# 1088 resting on {224, 1059}
# 837 resting on {944}
# 1168 resting on {953}
# 1191 resting on {418}
# 1317 resting on {514}
# 208 resting on {1142}
# 440 resting on {408}
# 723 resting on {1088}
# 860 resting on {1168}
# 888 resting on {418}
# 1137 resting on {944}
# 1207 resting on {1191}
# 194 resting on {1088}
# 406 resting on {860}
# 920 resting on {415}
# 398 resting on {860}
# 835 resting on {1207}
# 1107 resting on {1317}
# 1179 resting on {888}
# 171 resting on {208}
# 335 resting on {920}
# 706 resting on {440}
# 872 resting on {194}
# 926 resting on {1179}
# 985 resting on {406}
# 390 resting on {335}
# 534 resting on {398, 406}
# 948 resting on {265, 1179}
# 1352 resting on {398}
# 125 resting on {1107}
# 162 resting on {706}
# 1296 resting on {723}
# 69 resting on {985}
# 272 resting on {872}
# 427 resting on {926}
# 1027 resting on {534}
# 1176 resting on {872}
# 183 resting on {1352, 1296}
# 1023 resting on {125, 534}
# 51 resting on {427}
# 539 resting on {1027}
# 691 resting on {1176}
# 917 resting on {1027, 1023}
# 1003 resting on {125}
# 1095 resting on {69}
# 1116 resting on {162}
# 106 resting on {51, 335}
# 201 resting on {51}
# 585 resting on {1003}
# 831 resting on {51}
# 1082 resting on {539}
# 1180 resting on {1003}
# 3 resting on {585}
# 182 resting on {917}
# 333 resting on {1095}
# 373 resting on {106}
# 474 resting on {201}
# 725 resting on {585}
# 1288 resting on {201}
# 119 resting on {1082}
# 292 resting on {1288}
# 387 resting on {182}
# 1233 resting on {831}
# 240 resting on {474}
# 347 resting on {387}
# 368 resting on {119}
# 522 resting on {3}
# 668 resting on {1180}
# 220 resting on {347}
# 660 resting on {119}
# 963 resting on {240}
# 975 resting on {725}
# 1062 resting on {292}
# 206 resting on {240}
# 505 resting on {240}
# 1012 resting on {368}
# 1141 resting on {119}
# 1266 resting on {975}
# 1221 resting on {1062}
# 1250 resting on {368}
# 329 resting on {1266}
# 542 resting on {1012}
# 560 resting on {1250}
# 818 resting on {1062}
# 850 resting on {220}
# 138 resting on {850}
# 803 resting on {1012}
# 871 resting on {329}
# 1085 resting on {1250}
# 391 resting on {871}
# 471 resting on {560}
# 614 resting on {542}
# 1048 resting on {206}
# 92 resting on {1048}
# 517 resting on {391}
# 526 resting on {391}
# 688 resting on {1048}
# 237 resting on {92}
# 280 resting on {471}
# 577 resting on {688}
# 1089 resting on {803}
# 1120 resting on {688}
# 676 resting on {1085}
# 1301 resting on {614}
# 451 resting on {1120}
# 1014 resting on {1089}
# 73 resting on {577}
# 146 resting on {577}
# 164 resting on {1014}
# 172 resting on {1120, 237}
# 278 resting on {676}
# 399 resting on {676}
# 945 resting on {237}
# 252 resting on {945}
# 461 resting on {1301}
# 644 resting on {399}
# 15 resting on {451}
# 971 resting on {146}
# 568 resting on {451, 172}
# 1239 resting on {146}
# 1365 resting on {461}
# 114 resting on {252}
# 348 resting on {461}
# 570 resting on {15}
# 819 resting on {1239}
# 273 resting on {568}
# 695 resting on {73}
# 1319 resting on {570}
# 39 resting on {114}
# 666 resting on {348}
# 751 resting on {273}
# 911 resting on {1365}
# 1031 resting on {1319}
# 1058 resting on {1239}
# 1236 resting on {695}
# 1247 resting on {114}
# 326 resting on {273}
# 604 resting on {911}
# 711 resting on {348}
# 1096 resting on {644, 39, 695}
# 76 resting on {273}
# 239 resting on {751}
# 257 resting on {1058}
# 687 resting on {604}
# 150 resting on {1236}
# 1110 resting on {39}
# 689 resting on {150}
# 749 resting on {239}
# 779 resting on {711}
# 1008 resting on {1031}
# 49 resting on {257}
# 592 resting on {1110}
# 774 resting on {1096}
# 409 resting on {1008}
# 728 resting on {49}
# 243 resting on {779}
# 366 resting on {689}
# 626 resting on {49, 1236}
# 692 resting on {749}
# 995 resting on {1096, 49}
# 1308 resting on {774}
# 1071 resting on {592}
# 98 resting on {366}
# 767 resting on {1071}
# 0 resting on {995}
# 353 resting on {995}
# 363 resting on {366}
# 672 resting on {626}
# 1281 resting on {243}
# 1305 resting on {1281}
# 46 resting on {1008, 767}
# 354 resting on {363}
# 1255 resting on {353}
# 35 resting on {1281}
# 143 resting on {1255}
# 312 resting on {353}
# 423 resting on {672}
# 483 resting on {354}
# 457 resting on {483}
# 836 resting on {46, 143}
# 1182 resting on {354}
# 1367 resting on {98, 46}
# 362 resting on {35}
# 611 resting on {836}
# 628 resting on {423}
# 1053 resting on {46}
# 72 resting on {611}
# 211 resting on {312, 1255}
# 496 resting on {1367}
# 544 resting on {1182}
# 1190 resting on {483}
# 54 resting on {72}
# 365 resting on {628}
# 884 resting on {611}
# 914 resting on {1053, 1367}
# 1171 resting on {628}
# 1349 resting on {544}
# 969 resting on {365}
# 324 resting on {884}
# 446 resting on {365}
# 731 resting on {1171}
# 970 resting on {969}
# 32 resting on {731}
# 258 resting on {457}
# 620 resting on {970}
# 899 resting on {54}
# 929 resting on {446}
# 1204 resting on {446}
# 656 resting on {1190}
# 673 resting on {1204}
# 773 resting on {731}
# 868 resting on {32}
# 1150 resting on {969}
# 369 resting on {1150}
# 1049 resting on {731}
# 1061 resting on {446}
# 1252 resting on {32}
# 1267 resting on {970}
# 11 resting on {899}
# 507 resting on {929}
# 882 resting on {1252}
# 912 resting on {258}
# 919 resting on {656}
# 946 resting on {32}
# 989 resting on {369}
# 1211 resting on {1267, 620}
# 1273 resting on {673}
# 299 resting on {882}
# 434 resting on {946}
# 764 resting on {1273}
# 1016 resting on {673}
# 1044 resting on {673}
# 594 resting on {369}
# 968 resting on {989}
# 1035 resting on {1061}
# 1185 resting on {1016}
# 1242 resting on {764}
# 67 resting on {1185}
# 141 resting on {989}
# 463 resting on {1049}
# 865 resting on {1273, 1044}
# 877 resting on {1211}
# 949 resting on {968}
# 90 resting on {463}
# 177 resting on {434}
# 382 resting on {594}
# 448 resting on {1035}
# 931 resting on {1242}
# 1037 resting on {382}
# 1289 resting on {1211}
# 674 resting on {865}
# 814 resting on {1242}
# 1090 resting on {1289}
# 1366 resting on {949}
# 75 resting on {141}
# 509 resting on {1366}
# 646 resting on {90}
# 879 resting on {931, 814}
# 951 resting on {1289}
# 991 resting on {674}
# 305 resting on {931, 814}
# 412 resting on {646}
# 641 resting on {931}
# 957 resting on {646}
# 1101 resting on {448, 951}
# 255 resting on {814, 991}
# 537 resting on {646}
# 154 resting on {509}
# 621 resting on {951}
# 1029 resting on {879}
# 89 resting on {537, 412}
# 652 resting on {537}
# 696 resting on {621}
# 1099 resting on {957}
# 1194 resting on {1101}
# 155 resting on {255}
# 325 resting on {621}
# 1126 resting on {537, 412}
# 1135 resting on {154}
# 267 resting on {89}
# 490 resting on {1099}
# 1309 resting on {1099, 1126}
# 846 resting on {490, 1309}
# 294 resting on {1309}
# 529 resting on {267}
# 964 resting on {846}
# 572 resting on {964}
# 525 resting on {572}
# 1162 resting on {294}
# 1187 resting on {525}
# 300 resting on {1162}
# 1072 resting on {1162}
# 1025 resting on {1162}
# 1115 resting on {1072}
# 1147 resting on {1187}
# 40 resting on {1025}
# 797 resting on {1115}
# 1079 resting on {1115}
# 174 resting on {797}
# {0, 2, 4, 5, 8, 11, 12, 16, 19, 21, 24, 25, 26, 37, 40, 41, 42, 43, 47, 48, 50, 57, 58, 61, 62, 66, 67, 70, 71, 74, 75, 76, 77, 79, 81, 82, 85, 88, 93, 96, 97, 98, 101, 102, 105, 107, 108, 115, 116, 120, 124, 127, 128, 132, 135, 137, 138, 140, 143, 149, 155, 157, 158, 159, 160, 161, 164, 166, 170, 171, 172, 173, 174, 175, 177, 183, 184, 188, 192, 196, 200, 203, 210, 211, 214, 215, 217, 219, 224, 228, 232, 236, 238, 241, 244, 247, 250, 261, 265, 266, 269, 272, 274, 275, 278, 279, 280, 283, 289, 296, 298, 299, 300, 301, 302, 305, 306, 307, 311, 312, 315, 319, 322, 324, 325, 326, 332, 333, 334, 338, 339, 341, 342, 344, 346, 356, 357, 362, 367, 373, 375, 377, 383, 385, 386, 389, 390, 396, 400, 403, 404, 405, 407, 409, 411, 412, 413, 422, 430, 431, 436, 437, 439, 444, 445, 447, 448, 450, 454, 462, 466, 467, 468, 470, 473, 475, 478, 487, 489, 490, 493, 495, 496, 497, 504, 505, 507, 508, 517, 518, 519, 520, 522, 523, 526, 528, 529, 532, 533, 538, 546, 547, 551, 552, 557, 558, 559, 562, 569, 576, 582, 583, 584, 588, 590, 595, 596, 597, 603, 605, 606, 607, 612, 615, 618, 620, 622, 624, 627, 630, 631, 634, 635, 637, 641, 644, 647, 650, 651, 652, 653, 654, 655, 660, 661, 666, 668, 675, 683, 684, 687, 690, 691, 692, 694, 696, 700, 702, 705, 707, 710, 714, 715, 718, 728, 729, 739, 740, 741, 744, 752, 754, 757, 763, 765, 767, 770, 773, 790, 791, 793, 798, 800, 801, 805, 810, 811, 814, 815, 817, 818, 819, 820, 821, 833, 835, 837, 839, 843, 844, 847, 848, 852, 855, 866, 868, 869, 873, 876, 877, 881, 887, 889, 890, 891, 892, 893, 894, 895, 896, 898, 902, 906, 908, 912, 913, 914, 919, 921, 927, 930, 934, 939, 947, 948, 950, 954, 960, 963, 965, 971, 972, 973, 976, 983, 987, 991, 992, 1000, 1005, 1009, 1013, 1015, 1019, 1021, 1023, 1024, 1026, 1029, 1037, 1044, 1050, 1051, 1053, 1065, 1079, 1083, 1087, 1090, 1091, 1098, 1104, 1105, 1116, 1122, 1123, 1126, 1129, 1131, 1133, 1135, 1136, 1137, 1139, 1140, 1141, 1145, 1146, 1147, 1149, 1151, 1153, 1155, 1156, 1157, 1161, 1163, 1165, 1167, 1175, 1183, 1184, 1186, 1188, 1189, 1194, 1197, 1199, 1203, 1206, 1213, 1216, 1221, 1225, 1230, 1231, 1232, 1233, 1235, 1238, 1240, 1243, 1244, 1245, 1247, 1249, 1251, 1253, 1257, 1259, 1262, 1265, 1267, 1272, 1275, 1285, 1286, 1294, 1296, 1300, 1302, 1303, 1305, 1306, 1307, 1308, 1310, 1318, 1324, 1329, 1331, 1334, 1338, 1339, 1344, 1345, 1349, 1352, 1353, 1354, 1356, 1364, 1368}
# 463
# 158 resting on {-1}
# 197 resting on {-1}
# 288 resting on {-1}
# 649 resting on {-1}
# 655 resting on {-1}
# 1018 resting on {-1}
# 1215 resting on {-1}
# 1345 resting on {-1}
# 295 resting on {-1}
# 429 resting on {1215}
# 506 resting on {-1}
# 1122 resting on {-1}
# 1140 resting on {-1}
# 1201 resting on {-1}
# 1274 resting on {-1}
# 1314 resting on {197}
# 5 resting on {288}
# 77 resting on {1122, 655}
# 79 resting on {295}
# 215 resting on {-1}
# 247 resting on {-1}
# 251 resting on {429}
# 460 resting on {-1}
# 659 resting on {-1}
# 853 resting on {1274}
# 889 resting on {-1}
# 1054 resting on {-1}
# 134 resting on {1201}
# 555 resting on {1054}
# 590 resting on {288}
# 752 resting on {1018}
# 1028 resting on {853}
# 4 resting on {247, 655}
# 160 resting on {429}
# 170 resting on {649}
# 175 resting on {659}
# 200 resting on {1314}
# 478 resting on {555}
# 589 resting on {429}
# 815 resting on {1201, 1140}
# 852 resting on {506}
# 1001 resting on {853}
# 1145 resting on {251}
# 876 resting on {134}
# 1212 resting on {200, 79}
# 1213 resting on {1028}
# 234 resting on {1212}
# 686 resting on {460}
# 791 resting on {251}
# 981 resting on {1001}
# 1170 resting on {589}
# 118 resting on {686}
# 361 resting on {234}
# 600 resting on {981, 1213, 791}
# 671 resting on {1170}
# 1073 resting on {361}
# 1118 resting on {981}
# 1154 resting on {118}
# 1248 resting on {1170}
# 521 resting on {361}
# 643 resting on {118}
# 782 resting on {1154}
# 994 resting on {1248}
# 19 resting on {1073}
# 59 resting on {1073}
# 808 resting on {671}
# 1178 resting on {521}
# 1249 resting on {600}
# 1350 resting on {782}
# 122 resting on {1118}
# 386 resting on {1248}
# 388 resting on {643}
# 480 resting on {1118}
# 497 resting on {521}
# 763 resting on {671}
# 1262 resting on {994}
# 44 resting on {480, 1249}
# 310 resting on {808}
# 588 resting on {994}
# 845 resting on {59}
# 1038 resting on {1073}
# 161 resting on {480}
# 302 resting on {44}
# 693 resting on {480}
# 809 resting on {310}
# 864 resting on {1038}
# 1092 resting on {1350}
# 1246 resting on {763, 118}
# 60 resting on {1246}
# 85 resting on {388}
# 420 resting on {809}
# 1063 resting on {122}
# 1196 resting on {809}
# 467 resting on {864}
# 622 resting on {497, 19, 1038}
# 747 resting on {1178}
# 869 resting on {1063}
# 1133 resting on {845}
# 1344 resting on {1063}
# 244 resting on {60}
# 487 resting on {864}
# 627 resting on {1246}
# 1356 resting on {809}
# 1210 resting on {1196}
# 1251 resting on {747}
# 511 resting on {1210}
# 841 resting on {244, 1350}
# 913 resting on {1210}
# 1007 resting on {693}
# 1329 resting on {1092}
# 632 resting on {420}
# 757 resting on {841}
# 856 resting on {1133, 487}
# 992 resting on {1210}
# 546 resting on {1007}
# 781 resting on {1007}
# 881 resting on {856}
# 103 resting on {992, 511}
# 259 resting on {511}
# 1100 resting on {511}
# 364 resting on {632}
# 851 resting on {781}
# 1057 resting on {856}
# 1143 resting on {103}
# 551 resting on {259}
# 712 resting on {364}
# 741 resting on {1143}
# 977 resting on {103}
# 99 resting on {1100}
# 163 resting on {977}
# 250 resting on {1057}
# 839 resting on {712}
# 847 resting on {851}
# 783 resting on {99}
# 792 resting on {163}
# 308 resting on {783}
# 1173 resting on {308}
# 894 resting on {792}
# 967 resting on {1173}
# 678 resting on {1173}
# 765 resting on {1173}
# 1022 resting on {308}
# 645 resting on {967}
# 750 resting on {1022}
# 1326 resting on {894, 1022}
# 8 resting on {750, 765, 678, 967}
# 140 resting on {678}
# 469 resting on {645}
# 827 resting on {1022}
# 1091 resting on {1326}
# 1218 resting on {678}
# 1259 resting on {645}
# 485 resting on {1022}
# 1205 resting on {1218}
# 1245 resting on {1218}
# 1264 resting on {469}
# 104 resting on {1245, 1205}
# 179 resting on {827}
# 236 resting on {750, 967}
# 425 resting on {1259, 469}
# 558 resting on {827, 485}
# 810 resting on {1326}
# 1327 resting on {750}
# 203 resting on {1327}
# 959 resting on {8, 1218}
# 996 resting on {179}
# 139 resting on {104}
# 241 resting on {996}
# 298 resting on {959}
# 352 resting on {1205}
# 624 resting on {485}
# 903 resting on {179}
# 1065 resting on {1264}
# 26 resting on {1245, 959}
# 86 resting on {425}
# 256 resting on {624, 645}
# 662 resting on {810, 1091}
# 1159 resting on {1327}
# 1302 resting on {425}
# 422 resting on {1159}
# 698 resting on {959}
# 930 resting on {256}
# 309 resting on {256}
# 598 resting on {352}
# 987 resting on {139}
# 1183 resting on {903}
# 1208 resting on {662}
# 68 resting on {86}
# 350 resting on {256}
# 518 resting on {662}
# 1104 resting on {598}
# 1337 resting on {698}
# 458 resting on {309}
# 636 resting on {86, 1302}
# 1238 resting on {1208}
# 1243 resting on {1208}
# 383 resting on {636}
# 905 resting on {350}
# 53 resting on {458}
# 629 resting on {458}
# 928 resting on {905, 1243, 1238}
# 935 resting on {1337}
# 1172 resting on {68}
# 444 resting on {53}
# 495 resting on {636}
# 724 resting on {935}
# 824 resting on {928}
# 1224 resting on {629}
# 238 resting on {905}
# 531 resting on {53}
# 1050 resting on {1224}
# 1197 resting on {724}
# 1306 resting on {1172}
# 94 resting on {531}
# 152 resting on {1172}
# 395 resting on {935}
# 591 resting on {1172}
# 596 resting on {724}
# 631 resting on {724}
# 184 resting on {591}
# 187 resting on {1224}
# 323 resting on {824}
# 1002 resting on {152}
# 1320 resting on {531}
# 181 resting on {395}
# 285 resting on {1002}
# 341 resting on {94}
# 381 resting on {323}
# 543 resting on {323}
# 1068 resting on {1320}
# 61 resting on {187}
# 519 resting on {285}
# 702 resting on {1068}
# 925 resting on {1320}
# 116 resting on {543}
# 169 resting on {187}
# 246 resting on {925}
# 417 resting on {181}
# 479 resting on {1320}
# 605 resting on {381}
# 120 resting on {1068}
# 896 resting on {381, 543}
# 1020 resting on {169}
# 1125 resting on {246}
# 1231 resting on {285}
# 1237 resting on {417}
# 421 resting on {479}
# 432 resting on {417}
# 135 resting on {1125}
# 142 resting on {1237}
# 315 resting on {1020}
# 581 resting on {1125}
# 955 resting on {421, 246}
# 1354 resting on {421}
# 437 resting on {581, 285}
# 891 resting on {581}
# 1151 resting on {1237}
# 91 resting on {891, 1231}
# 452 resting on {432}
# 768 resting on {955}
# 758 resting on {142}
# 1202 resting on {142}
# 1364 resting on {1202}
# 473 resting on {91}
# 1074 resting on {768}
# 1124 resting on {1202, 758}
# 1244 resting on {452}
# 938 resting on {1074}
# 965 resting on {758}
# 37 resting on {938}
# 1225 resting on {938}
# 1347 resting on {1124}
# 1134 resting on {1124}
# 1166 resting on {1347}
# 227 resting on {1166}
# 557 resting on {1166}
# 997 resting on {1347}
# 222 resting on {227}
# 663 resting on {1134}
# 1254 resting on {1166}
# 84 resting on {663}
# 293 resting on {227}
# 563 resting on {997, 663}
# 651 resting on {997}
# 320 resting on {1254}
# 550 resting on {222}
# 934 resting on {227}
# 340 resting on {293}
# 413 resting on {320}
# 523 resting on {320, 222}
# 816 resting on {222}
# 828 resting on {293}
# 130 resting on {563}
# 667 resting on {828}
# 756 resting on {816}
# 402 resting on {667}
# 453 resting on {320}
# 1155 resting on {130}
# 1310 resting on {550}
# 129 resting on {756}
# 527 resting on {340}
# 780 resting on {84}
# 1060 resting on {402}
# 29 resting on {1155, 413}
# 416 resting on {756}
# 481 resting on {130}
# 1138 resting on {780}
# 330 resting on {527}
# 704 resting on {129}
# 740 resting on {1060}
# 785 resting on {416}
# 1019 resting on {481}
# 1312 resting on {1138}
# 374 resting on {527}
# 431 resting on {1138}
# 447 resting on {453}
# 547 resting on {29}
# 727 resting on {527}
# 1362 resting on {330}
# 392 resting on {1312}
# 1268 resting on {1312}
# 435 resting on {704}
# 617 resting on {785}
# 769 resting on {1362}
# 843 resting on {1268}
# 1121 resting on {727}
# 1298 resting on {374}
# 198 resting on {1121}
# 690 resting on {1362}
# 892 resting on {435}
# 1117 resting on {1121}
# 1123 resting on {1298}
# 1285 resting on {617}
# 1340 resting on {1268}
# 1341 resting on {392}
# 1346 resting on {617}
# 574 resting on {1340}
# 1032 resting on {1340}
# 1158 resting on {769}
# 204 resting on {1158}
# 603 resting on {1158}
# 637 resting on {1032}
# 754 resting on {1346}
# 875 resting on {1032}
# 1084 resting on {198}
# 1109 resting on {1117}
# 321 resting on {1341}
# 376 resting on {754, 1123}
# 607 resting on {1032}
# 721 resting on {1032}
# 1021 resting on {1109}
# 25 resting on {574}
# 915 resting on {1084}
# 168 resting on {721}
# 499 resting on {875}
# 515 resting on {204}
# 1220 resting on {1109}
# 58 resting on {637, 607}
# 682 resting on {321}
# 960 resting on {1220}
# 1167 resting on {376}
# 269 resting on {321}
# 601 resting on {168}
# 722 resting on {168}
# 820 resting on {915}
# 885 resting on {722}
# 1261 resting on {601}
# 159 resting on {960, 820}
# 209 resting on {515}
# 290 resting on {499}
# 561 resting on {290}
# 736 resting on {1261}
# 1258 resting on {1341}
# 1263 resting on {885}
# 316 resting on {1263}
# 223 resting on {316}
# 503 resting on {209}
# 1357 resting on {1258}
# 117 resting on {1258}
# 303 resting on {1263}
# 389 resting on {736}
# 486 resting on {1357}
# 647 resting on {1263}
# 916 resting on {682}
# 1290 resting on {503}
# 45 resting on {486}
# 62 resting on {223}
# 355 resting on {1290}
# 464 resting on {303}
# 1174 resting on {561}
# 42 resting on {355}
# 151 resting on {117}
# 697 resting on {1174}
# 1056 resting on {916}
# 1311 resting on {1290}
# 385 resting on {697}
# 794 resting on {45}
# 133 resting on {1056}
# 173 resting on {133}
# 317 resting on {1056}
# 866 resting on {1311}
# 874 resting on {1056}
# 984 resting on {151}
# 414 resting on {317}
# 606 resting on {133}
# 630 resting on {464}
# 954 resting on {794}
# 149 resting on {874}
# 939 resting on {173, 606}
# 263 resting on {317}
# 638 resting on {984}
# 830 resting on {414}
# 973 resting on {984}
# 1105 resting on {973, 638}
# 633 resting on {638}
# 1005 resting on {263}
# 17 resting on {263}
# 909 resting on {633}
# 157 resting on {17}
# 1265 resting on {909}
# 199 resting on {633}
# 615 resting on {830}
# 760 resting on {909}
# 910 resting on {909}
# 144 resting on {760}
# 709 resting on {910}
# 802 resting on {199}
# 1368 resting on {144}
# 609 resting on {1265, 910}
# 789 resting on {802}
# 1322 resting on {954, 802}
# 87 resting on {144}
# 700 resting on {1322}
# 717 resting on {709}
# 793 resting on {609}
# 743 resting on {609}
# 1004 resting on {789}
# 1227 resting on {609}
# 520 resting on {717}
# 190 resting on {743}
# 500 resting on {1227}
# 1241 resting on {1227, 1004}
# 730 resting on {743}
# 742 resting on {190}
# 762 resting on {1004}
# 1287 resting on {1241}
# 186 resting on {1287}
# 322 resting on {742}
# 653 resting on {1287}
# 489 resting on {730}
# 759 resting on {87}
# 1198 resting on {742}
# 1284 resting on {186}
# 112 resting on {500}
# 501 resting on {762}
# 1013 resting on {762}
# 1181 resting on {762}
# 1230 resting on {759}
# 832 resting on {501}
# 1272 resting on {1284}
# 13 resting on {1198}
# 43 resting on {832}
# 281 resting on {1181}
# 338 resting on {1013, 1181}
# 491 resting on {1181}
# 1113 resting on {112}
# 216 resting on {13}
# 262 resting on {501}
# 1139 resting on {281}
# 1277 resting on {832}
# 772 resting on {216}
# 1127 resting on {1113}
# 231 resting on {1127}
# 301 resting on {491}
# 1295 resting on {1127}
# 124 resting on {1139, 301}
# 145 resting on {262}
# 932 resting on {772}
# 360 resting on {1277}
# 449 resting on {145}
# 1119 resting on {231}
# 1136 resting on {1295}
# 1156 resting on {449}
# 1228 resting on {932}
# 113 resting on {449}
# 148 resting on {1119}
# 454 resting on {360}
# 393 resting on {360}
# 1103 resting on {1119}
# 66 resting on {1295}
# 83 resting on {393}
# 532 resting on {1228}
# 729 resting on {148}
# 893 resting on {113}
# 1291 resting on {393}
# 14 resting on {1103}
# 433 resting on {893, 231}
# 456 resting on {393}
# 1339 resting on {66, 1119}
# 580 resting on {433}
# 746 resting on {456}
# 202 resting on {580}
# 559 resting on {14}
# 823 resting on {83}
# 1070 resting on {1291}
# 410 resting on {456}
# 901 resting on {580}
# 95 resting on {746}
# 472 resting on {746}
# 683 resting on {823}
# 838 resting on {410}
# 6 resting on {901}
# 78 resting on {1070}
# 156 resting on {202}
# 10 resting on {78}
# 176 resting on {78}
# 372 resting on {472}
# 701 resting on {6}
# 1232 resting on {78}
# 306 resting on {701}
# 332 resting on {95}
# 384 resting on {10}
# 923 resting on {372}
# 34 resting on {10}
# 132 resting on {838}
# 533 resting on {78}
# 1188 resting on {384}
# 1223 resting on {176}
# 1234 resting on {10}
# 1257 resting on {156}
# 1292 resting on {923}
# 411 resting on {176, 10}
# 998 resting on {34}
# 1240 resting on {701}
# 313 resting on {1234}
# 807 resting on {1223}
# 137 resting on {998}
# 253 resting on {34}
# 1040 resting on {1292}
# 346 resting on {1040}
# 538 resting on {313}
# 937 resting on {1188, 807}
# 343 resting on {253}
# 657 resting on {937}
# 1086 resting on {807}
# 608 resting on {937}
# 748 resting on {657}
# 777 resting on {253}
# 1041 resting on {657}
# 801 resting on {608}
# 1146 resting on {608}
# 468 resting on {1086}
# 825 resting on {343}
# 1010 resting on {1041}
# 1098 resting on {748}
# 279 resting on {801, 1146}
# 870 resting on {777}
# 1111 resting on {748}
# 64 resting on {1010}
# 494 resting on {1111}
# 545 resting on {825}
# 1222 resting on {1111}
# 1282 resting on {870}
# 65 resting on {64}
# 123 resting on {870}
# 345 resting on {1282}
# 1217 resting on {1222}
# 1280 resting on {64}
# 1342 resting on {494}
# 1355 resting on {1222}
# 276 resting on {65}
# 775 resting on {1217}
# 833 resting on {1280}
# 1271 resting on {1355}
# 96 resting on {775}
# 419 resting on {1342}
# 488 resting on {545}
# 650 resting on {1271}
# 1087 resting on {123}
# 289 resting on {345}
# 679 resting on {419}
# 806 resting on {1217}
# 983 resting on {1355}
# 1276 resting on {1355}
# 599 resting on {276}
# 849 resting on {419, 983}
# 1077 resting on {488}
# 136 resting on {1077}
# 196 resting on {849}
# 634 resting on {1276}
# 842 resting on {679}
# 990 resting on {419}
# 1269 resting on {1276}
# 1286 resting on {599}
# 287 resting on {849}
# 396 resting on {1269}
# 554 resting on {634, 1269}
# 1097 resting on {1077}
# 93 resting on {1097}
# 212 resting on {806}
# 380 resting on {990}
# 670 resting on {287}
# 465 resting on {670}
# 962 resting on {554}
# 1219 resting on {380}
# 356 resting on {670}
# 371 resting on {136}
# 428 resting on {380}
# 587 resting on {842}
# 97 resting on {428}
# 734 resting on {465}
# 1108 resting on {428}
# 1235 resting on {962}
# 1256 resting on {371}
# 9 resting on {962}
# 41 resting on {1219}
# 205 resting on {371}
# 260 resting on {428}
# 430 resting on {1219}
# 582 resting on {1256}
# 1034 resting on {962}
# 1177 resting on {587}
# 2 resting on {371}
# 311 resting on {260}
# 336 resting on {1034}
# 787 resting on {734}
# 834 resting on {1177}
# 80 resting on {41, 430}
# 193 resting on {787}
# 873 resting on {260}
# 1083 resting on {1108}
# 1163 resting on {834}
# 18 resting on {834}
# 31 resting on {873, 582}
# 442 resting on {9}
# 826 resting on {9}
# 829 resting on {212}
# 943 resting on {205}
# 291 resting on {18}
# 578 resting on {80}
# 1203 resting on {834}
# 47 resting on {578}
# 328 resting on {31}
# 401 resting on {826}
# 426 resting on {829}
# 512 resting on {336}
# 541 resting on {587}
# 575 resting on {943}
# 1299 resting on {193}
# 661 resting on {442}
# 707 resting on {575}
# 761 resting on {1299}
# 862 resting on {328}
# 1000 resting on {575}
# 1015 resting on {512}
# 1323 resting on {328}
# 56 resting on {291}
# 319 resting on {401}
# 855 resting on {761}
# 880 resting on {18}
# 1324 resting on {578}
# 180 resting on {541}
# 597 resting on {426}
# 1331 resting on {1299}
# 367 resting on {1323}
# 988 resting on {880}
# 1279 resting on {1323}
# 1348 resting on {880}
# 466 resting on {1279}
# 221 resting on {180}
# 274 resting on {761, 1331}
# 436 resting on {1279}
# 1303 resting on {988}
# 100 resting on {56}
# 297 resting on {221}
# 753 resting on {862}
# 1186 resting on {988}
# 126 resting on {1348}
# 459 resting on {100}
# 854 resting on {126}
# 1067 resting on {297}
# 1336 resting on {126}
# 191 resting on {753}
# 275 resting on {1336}
# 314 resting on {297}
# 593 resting on {459}
# 654 resting on {459}
# 30 resting on {854}
# 307 resting on {854}
# 549 resting on {593}
# 1043 resting on {314}
# 82 resting on {1043}
# 979 resting on {191}
# 986 resting on {30}
# 1069 resting on {1067}
# 178 resting on {593}
# 219 resting on {1043}
# 739 resting on {1336}
# 12 resting on {30}
# 153 resting on {986}
# 218 resting on {986}
# 351 resting on {307, 30}
# 536 resting on {549}
# 719 resting on {178}
# 732 resting on {1336}
# 1114 resting on {986}
# 1175 resting on {979}
# 498 resting on {351}
# 510 resting on {153}
# 524 resting on {1069}
# 840 resting on {218}
# 961 resting on {1114}
# 1026 resting on {732}
# 798 resting on {961}
# 813 resting on {498}
# 858 resting on {536}
# 16 resting on {218}
# 33 resting on {719}
# 282 resting on {858}
# 404 resting on {719}
# 978 resting on {510}
# 1148 resting on {498}
# 1278 resting on {524}
# 1353 resting on {524}
# 127 resting on {282}
# 235 resting on {1148}
# 304 resting on {961}
# 703 resting on {978}
# 976 resting on {840}
# 1189 resting on {858}
# 569 resting on {33}
# 610 resting on {1278}
# 699 resting on {1353, 307}
# 1226 resting on {304, 798}
# 1300 resting on {703}
# 1304 resting on {813}
# 232 resting on {282, 1189}
# 623 resting on {304}
# 898 resting on {1226}
# 952 resting on {699}
# 972 resting on {1226}
# 331 resting on {610}
# 400 resting on {898, 972}
# 844 resting on {1304}
# 249 resting on {623}
# 1080 resting on {331}
# 55 resting on {952}
# 1006 resting on {235}
# 1169 resting on {1080}
# 658 resting on {249}
# 922 resting on {331}
# 370 resting on {1006}
# 571 resting on {1006}
# 685 resting on {658}
# 1153 resting on {922}
# 424 resting on {370}
# 504 resting on {55}
# 616 resting on {922}
# 1338 resting on {370}
# 131 resting on {616, 1153}
# 936 resting on {616}
# 1206 resting on {658}
# 74 resting on {616}
# 229 resting on {936, 131}
# 675 resting on {370}
# 713 resting on {571}
# 958 resting on {685}
# 1369 resting on {1169}
# 167 resting on {936}
# 375 resting on {1369}
# 482 resting on {424, 1338, 675}
# 890 resting on {131}
# 993 resting on {616}
# 1131 resting on {713}
# 1333 resting on {424}
# 63 resting on {229, 167}
# 166 resting on {713}
# 214 resting on {1369}
# 553 resting on {229}
# 897 resting on {229}
# 283 resting on {553}
# 441 resting on {958}
# 694 resting on {958}
# 799 resting on {958}
# 908 resting on {993}
# 1275 resting on {897}
# 27 resting on {897}
# 102 resting on {63}
# 105 resting on {799}
# 337 resting on {167}
# 443 resting on {482}
# 921 resting on {1333}
# 1076 resting on {482}
# 484 resting on {443}
# 677 resting on {553}
# 111 resting on {27}
# 784 resting on {441}
# 681 resting on {784}
# 942 resting on {784}
# 1078 resting on {1076}
# 1165 resting on {1275, 102}
# 22 resting on {677}
# 165 resting on {484}
# 188 resting on {908, 102}
# 705 resting on {111}
# 980 resting on {337}
# 1193 resting on {942}
# 508 resting on {165}
# 602 resting on {1078}
# 1039 resting on {1193}
# 50 resting on {980}
# 1216 resting on {602}
# 121 resting on {1039}
# 233 resting on {50, 443}
# 397 resting on {22}
# 548 resting on {165}
# 1046 resting on {681}
# 811 resting on {1046}
# 861 resting on {397}
# 1307 resting on {1046}
# 795 resting on {121}
# 974 resting on {548}
# 1260 resting on {233}
# 584 resting on {861}
# 618 resting on {795}
# 733 resting on {861}
# 23 resting on {1260}
# 147 resting on {974}
# 225 resting on {795}
# 1294 resting on {733}
# 342 resting on {508, 23}
# 567 resting on {225}
# 625 resting on {147}
# 1157 resting on {225}
# 735 resting on {1260}
# 906 resting on {1157, 567}
# 1051 resting on {733}
# 1315 resting on {625}
# 264 resting on {1046}
# 403 resting on {1315}
# 1036 resting on {23}
# 1200 resting on {1315}
# 1316 resting on {735}
# 493 resting on {1316}
# 714 resting on {567}
# 1011 resting on {1316}
# 57 resting on {735}
# 648 resting on {1200}
# 940 resting on {264}
# 1106 resting on {1316}
# 21 resting on {1036}
# 438 resting on {1307, 264, 811}
# 477 resting on {648}
# 918 resting on {940, 438}
# 1055 resting on {477}
# 1102 resting on {1011}
# 1149 resting on {940}
# 530 resting on {1106}
# 583 resting on {1102}
# 878 resting on {1102}
# 1363 resting on {438}
# 109 resting on {1363}
# 296 resting on {530}
# 579 resting on {878}
# 639 resting on {878}
# 1144 resting on {878}
# 1283 resting on {648}
# 1360 resting on {1055}
# 88 resting on {530}
# 394 resting on {918}
# 516 resting on {579}
# 595 resting on {1200}
# 902 resting on {1283, 477}
# 904 resting on {1360}
# 24 resting on {109}
# 217 resting on {1144}
# 716 resting on {109}
# 788 resting on {109}
# 1359 resting on {904}
# 107 resting on {1283}
# 192 resting on {516}
# 195 resting on {1359}
# 708 resting on {639}
# 817 resting on {516}
# 895 resting on {394}
# 439 resting on {296, 88}
# 564 resting on {788}
# 1066 resting on {708}
# 1330 resting on {716}
# 185 resting on {788}
# 848 resting on {1330}
# 377 resting on {848, 403}
# 715 resting on {185}
# 726 resting on {564}
# 857 resting on {185}
# 1033 resting on {192, 817}
# 1199 resting on {195}
# 1229 resting on {1066}
# 562 resting on {1033}
# 565 resting on {1330}
# 1112 resting on {1229}
# 1293 resting on {1033}
# 242 resting on {726}
# 540 resting on {1293}
# 642 resting on {857}
# 1 resting on {565}
# 248 resting on {1112}
# 357 resting on {242}
# 1047 resting on {1293}
# 210 resting on {540}
# 1332 resting on {642}
# 28 resting on {540}
# 349 resting on {540}
# 1064 resting on {1047}
# 327 resting on {1}
# 566 resting on {349}
# 800 resting on {28}
# 812 resting on {248}
# 1045 resting on {1}
# 445 resting on {812}
# 941 resting on {1332}
# 528 resting on {327}
# 535 resting on {800, 566}
# 999 resting on {1064}
# 1184 resting on {812}
# 70 resting on {812}
# 81 resting on {941}
# 1081 resting on {1045}
# 1253 resting on {566}
# 1318 resting on {566}
# 1361 resting on {941}
# 640 resting on {941}
# 669 resting on {1318, 535}
# 907 resting on {1361}
# 684 resting on {999}
# 1321 resting on {535}
# 720 resting on {907}
# 1328 resting on {640}
# 266 resting on {669}
# 379 resting on {720}
# 745 resting on {720}
# 766 resting on {1081}
# 1075 resting on {1321, 669}
# 1325 resting on {1321}
# 7 resting on {1328}
# 405 resting on {379}
# 755 resting on {766}
# 786 resting on {720}
# 950 resting on {745}
# 1334 resting on {745}
# 455 resting on {755}
# 502 resting on {1325}
# 1214 resting on {907, 766}
# 108 resting on {786}
# 228 resting on {1075}
# 245 resting on {379}
# 737 resting on {266, 1075}
# 956 resting on {755}
# 1209 resting on {455}
# 36 resting on {502}
# 128 resting on {455}
# 230 resting on {956}
# 115 resting on {1214}
# 271 resting on {36}
# 344 resting on {737}
# 863 resting on {1209}
# 1132 resting on {7}
# 664 resting on {230}
# 718 resting on {245}
# 982 resting on {1132}
# 900 resting on {1132}
# 1270 resting on {271}
# 189 resting on {1270}
# 552 resting on {982}
# 790 resting on {271}
# 1009 resting on {245}
# 1160 resting on {664}
# 1130 resting on {900}
# 1152 resting on {863}
# 268 resting on {900}
# 318 resting on {900}
# 378 resting on {1270}
# 573 resting on {189}
# 966 resting on {1160}
# 1094 resting on {1160}
# 334 resting on {966}
# 613 resting on {1130}
# 1042 resting on {1152}
# 38 resting on {573}
# 492 resting on {1152}
# 778 resting on {1130}
# 886 resting on {1042}
# 1161 resting on {1152}
# 1343 resting on {1042}
# 213 resting on {1094}
# 450 resting on {318}
# 475 resting on {886}
# 612 resting on {886}
# 796 resting on {573}
# 821 resting on {886}
# 1358 resting on {378}
# 71 resting on {38}
# 207 resting on {268}
# 513 resting on {213}
# 805 resting on {778}
# 1052 resting on {1343}
# 1129 resting on {613}
# 339 resting on {796, 38}
# 635 resting on {778, 613}
# 710 resting on {1358}
# 883 resting on {492}
# 1024 resting on {207}
# 284 resting on {796}
# 1128 resting on {1052}
# 680 resting on {207}
# 1030 resting on {513}
# 619 resting on {284}
# 1017 resting on {883}
# 226 resting on {1030}
# 476 resting on {1017}
# 771 resting on {1017}
# 859 resting on {1128}
# 407 resting on {680}
# 470 resting on {1017}
# 1313 resting on {859}
# 110 resting on {476}
# 286 resting on {619}
# 462 resting on {1313}
# 665 resting on {226}
# 48 resting on {771}
# 887 resting on {859}
# 358 resting on {110}
# 738 resting on {1313}
# 867 resting on {771, 470}
# 254 resting on {738}
# 556 resting on {867}
# 804 resting on {665}
# 924 resting on {1313, 887}
# 52 resting on {738}
# 224 resting on {254}
# 586 resting on {924}
# 770 resting on {286}
# 822 resting on {867}
# 1335 resting on {358}
# 1351 resting on {556}
# 927 resting on {556}
# 947 resting on {804}
# 101 resting on {1351}
# 359 resting on {52}
# 576 resting on {822}
# 776 resting on {822}
# 1059 resting on {586}
# 1093 resting on {1351}
# 1195 resting on {556, 822}
# 1297 resting on {1335}
# 933 resting on {1093}
# 1164 resting on {1297}
# 1192 resting on {1093}
# 20 resting on {1195}
# 270 resting on {359}
# 277 resting on {933}
# 408 resting on {1164}
# 953 resting on {1059}
# 1142 resting on {1297}
# 261 resting on {1093}
# 265 resting on {20}
# 415 resting on {277}
# 418 resting on {776}
# 514 resting on {953}
# 744 resting on {270}
# 944 resting on {1192}
# 1088 resting on {224, 1059}
# 837 resting on {944}
# 1168 resting on {953}
# 1191 resting on {418}
# 1317 resting on {514}
# 208 resting on {1142}
# 440 resting on {408}
# 723 resting on {1088}
# 860 resting on {1168}
# 888 resting on {418}
# 1137 resting on {944}
# 1207 resting on {1191}
# 194 resting on {1088}
# 406 resting on {860}
# 920 resting on {415}
# 398 resting on {860}
# 835 resting on {1207}
# 1107 resting on {1317}
# 1179 resting on {888}
# 171 resting on {208}
# 335 resting on {920}
# 706 resting on {440}
# 872 resting on {194}
# 926 resting on {1179}
# 985 resting on {406}
# 390 resting on {335}
# 534 resting on {398, 406}
# 948 resting on {265, 1179}
# 1352 resting on {398}
# 125 resting on {1107}
# 162 resting on {706}
# 1296 resting on {723}
# 69 resting on {985}
# 272 resting on {872}
# 427 resting on {926}
# 1027 resting on {534}
# 1176 resting on {872}
# 183 resting on {1352, 1296}
# 1023 resting on {125, 534}
# 51 resting on {427}
# 539 resting on {1027}
# 691 resting on {1176}
# 917 resting on {1027, 1023}
# 1003 resting on {125}
# 1095 resting on {69}
# 1116 resting on {162}
# 106 resting on {51, 335}
# 201 resting on {51}
# 585 resting on {1003}
# 831 resting on {51}
# 1082 resting on {539}
# 1180 resting on {1003}
# 3 resting on {585}
# 182 resting on {917}
# 333 resting on {1095}
# 373 resting on {106}
# 474 resting on {201}
# 725 resting on {585}
# 1288 resting on {201}
# 119 resting on {1082}
# 292 resting on {1288}
# 387 resting on {182}
# 1233 resting on {831}
# 240 resting on {474}
# 347 resting on {387}
# 368 resting on {119}
# 522 resting on {3}
# 668 resting on {1180}
# 220 resting on {347}
# 660 resting on {119}
# 963 resting on {240}
# 975 resting on {725}
# 1062 resting on {292}
# 206 resting on {240}
# 505 resting on {240}
# 1012 resting on {368}
# 1141 resting on {119}
# 1266 resting on {975}
# 1221 resting on {1062}
# 1250 resting on {368}
# 329 resting on {1266}
# 542 resting on {1012}
# 560 resting on {1250}
# 818 resting on {1062}
# 850 resting on {220}
# 138 resting on {850}
# 803 resting on {1012}
# 871 resting on {329}
# 1085 resting on {1250}
# 391 resting on {871}
# 471 resting on {560}
# 614 resting on {542}
# 1048 resting on {206}
# 92 resting on {1048}
# 517 resting on {391}
# 526 resting on {391}
# 688 resting on {1048}
# 237 resting on {92}
# 280 resting on {471}
# 577 resting on {688}
# 1089 resting on {803}
# 1120 resting on {688}
# 676 resting on {1085}
# 1301 resting on {614}
# 451 resting on {1120}
# 1014 resting on {1089}
# 73 resting on {577}
# 146 resting on {577}
# 164 resting on {1014}
# 172 resting on {1120, 237}
# 278 resting on {676}
# 399 resting on {676}
# 945 resting on {237}
# 252 resting on {945}
# 461 resting on {1301}
# 644 resting on {399}
# 15 resting on {451}
# 971 resting on {146}
# 568 resting on {451, 172}
# 1239 resting on {146}
# 1365 resting on {461}
# 114 resting on {252}
# 348 resting on {461}
# 570 resting on {15}
# 819 resting on {1239}
# 273 resting on {568}
# 695 resting on {73}
# 1319 resting on {570}
# 39 resting on {114}
# 666 resting on {348}
# 751 resting on {273}
# 911 resting on {1365}
# 1031 resting on {1319}
# 1058 resting on {1239}
# 1236 resting on {695}
# 1247 resting on {114}
# 326 resting on {273}
# 604 resting on {911}
# 711 resting on {348}
# 1096 resting on {644, 39, 695}
# 76 resting on {273}
# 239 resting on {751}
# 257 resting on {1058}
# 687 resting on {604}
# 150 resting on {1236}
# 1110 resting on {39}
# 689 resting on {150}
# 749 resting on {239}
# 779 resting on {711}
# 1008 resting on {1031}
# 49 resting on {257}
# 592 resting on {1110}
# 774 resting on {1096}
# 409 resting on {1008}
# 728 resting on {49}
# 243 resting on {779}
# 366 resting on {689}
# 626 resting on {49, 1236}
# 692 resting on {749}
# 995 resting on {1096, 49}
# 1308 resting on {774}
# 1071 resting on {592}
# 98 resting on {366}
# 767 resting on {1071}
# 0 resting on {995}
# 353 resting on {995}
# 363 resting on {366}
# 672 resting on {626}
# 1281 resting on {243}
# 1305 resting on {1281}
# 46 resting on {1008, 767}
# 354 resting on {363}
# 1255 resting on {353}
# 35 resting on {1281}
# 143 resting on {1255}
# 312 resting on {353}
# 423 resting on {672}
# 483 resting on {354}
# 457 resting on {483}
# 836 resting on {46, 143}
# 1182 resting on {354}
# 1367 resting on {98, 46}
# 362 resting on {35}
# 611 resting on {836}
# 628 resting on {423}
# 1053 resting on {46}
# 72 resting on {611}
# 211 resting on {312, 1255}
# 496 resting on {1367}
# 544 resting on {1182}
# 1190 resting on {483}
# 54 resting on {72}
# 365 resting on {628}
# 884 resting on {611}
# 914 resting on {1053, 1367}
# 1171 resting on {628}
# 1349 resting on {544}
# 969 resting on {365}
# 324 resting on {884}
# 446 resting on {365}
# 731 resting on {1171}
# 970 resting on {969}
# 32 resting on {731}
# 258 resting on {457}
# 620 resting on {970}
# 899 resting on {54}
# 929 resting on {446}
# 1204 resting on {446}
# 656 resting on {1190}
# 673 resting on {1204}
# 773 resting on {731}
# 868 resting on {32}
# 1150 resting on {969}
# 369 resting on {1150}
# 1049 resting on {731}
# 1061 resting on {446}
# 1252 resting on {32}
# 1267 resting on {970}
# 11 resting on {899}
# 507 resting on {929}
# 882 resting on {1252}
# 912 resting on {258}
# 919 resting on {656}
# 946 resting on {32}
# 989 resting on {369}
# 1211 resting on {1267, 620}
# 1273 resting on {673}
# 299 resting on {882}
# 434 resting on {946}
# 764 resting on {1273}
# 1016 resting on {673}
# 1044 resting on {673}
# 594 resting on {369}
# 968 resting on {989}
# 1035 resting on {1061}
# 1185 resting on {1016}
# 1242 resting on {764}
# 67 resting on {1185}
# 141 resting on {989}
# 463 resting on {1049}
# 865 resting on {1273, 1044}
# 877 resting on {1211}
# 949 resting on {968}
# 90 resting on {463}
# 177 resting on {434}
# 382 resting on {594}
# 448 resting on {1035}
# 931 resting on {1242}
# 1037 resting on {382}
# 1289 resting on {1211}
# 674 resting on {865}
# 814 resting on {1242}
# 1090 resting on {1289}
# 1366 resting on {949}
# 75 resting on {141}
# 509 resting on {1366}
# 646 resting on {90}
# 879 resting on {931, 814}
# 951 resting on {1289}
# 991 resting on {674}
# 305 resting on {931, 814}
# 412 resting on {646}
# 641 resting on {931}
# 957 resting on {646}
# 1101 resting on {448, 951}
# 255 resting on {814, 991}
# 537 resting on {646}
# 154 resting on {509}
# 621 resting on {951}
# 1029 resting on {879}
# 89 resting on {537, 412}
# 652 resting on {537}
# 696 resting on {621}
# 1099 resting on {957}
# 1194 resting on {1101}
# 155 resting on {255}
# 325 resting on {621}
# 1126 resting on {537, 412}
# 1135 resting on {154}
# 267 resting on {89}
# 490 resting on {1099}
# 1309 resting on {1099, 1126}
# 846 resting on {490, 1309}
# 294 resting on {1309}
# 529 resting on {267}
# 964 resting on {846}
# 572 resting on {964}
# 525 resting on {572}
# 1162 resting on {294}
# 1187 resting on {525}
# 300 resting on {1162}
# 1072 resting on {1162}
# 1025 resting on {1162}
# 1115 resting on {1072}
# 1147 resting on {1187}
# 40 resting on {1025}
# 797 resting on {1115}
# 1079 resting on {1115}
# 174 resting on {797}
# 89727
